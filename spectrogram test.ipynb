# %%
pip install nlpaug numpy pandas librosa
# Out:
# Requirement already satisfied: nlpaug in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (1.1.7)
# Requirement already satisfied: numpy in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (1.19.5)
# Requirement already satisfied: pandas in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (1.1.5)
# Requirement already satisfied: librosa in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (0.9.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (1.5.4)
# Requirement already satisfied: joblib>=0.14 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (1.1.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: numba>=0.45.1 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (0.53.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (0.4.2)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (21.3)
# Requirement already satisfied: pooch>=1.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from numba>=0.45.1->librosa) (0.36.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.5.30)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\phitt\.conda\envs\spectrogram\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa>=0.9.1 matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from nlpaug.util.audio.loader import AudioLoader
from nlpaug.util.audio.visualizer import AudioVisualizer

path = r'C:\Users\phitt\OneDrive\Desktop\MY project\ICBHI DATASET\ICBHI_final_database\ICBHI_final_database\101_1b1_Al_sc_Meditron.wav'

data = AudioLoader.load_mel_spectrogram(path, n_mels=128)
AudioVisualizer.spectrogram('Original', data)

# %%
import nlpaug.augmenter.spectrogram as nas
import nlpaug.flow as naf

# %%
aug = nas.FrequencyMaskingAug(zone=(0, 1))

aug_data = aug.substitute(data)
AudioVisualizer.spectrogram('Frequency Masking', aug_data)

# %%
aug = nas.TimeMaskingAug(zone=(0, 1))

aug_data = aug.substitute(data)
AudioVisualizer.spectrogram('Time Masking', aug_data)

# %%
aug = nas.LoudnessAug()

aug_data = aug.substitute(data)
AudioVisualizer.spectrogram('Loudness', aug_data)

# %%
import nlpaug.flow as naf

flow = naf.Sequential([
    nas.FrequencyMaskingAug(), 
    nas.TimeMaskingAug(), 
])
aug_data = flow.augment(data)
AudioVisualizer.spectrogram('Combine Frequency Masking and Time Masking', aug_data)
